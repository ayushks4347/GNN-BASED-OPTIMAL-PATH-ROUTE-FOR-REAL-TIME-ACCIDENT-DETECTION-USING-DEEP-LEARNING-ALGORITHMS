# %%
from ultralytics import YOLO
import cv2

# %%
import os

for root, dirs, files in os.walk("runs"):
    for file in files:
        if file == "best.pt":
            print(os.path.join(root, file))
# Out:
# runs\detect\accident_yolov87\weights\best.pt

# %%
# ✅ Use the correct path to your trained model
model = YOLO("runs/detect/accident_yolov87/weights/best.pt")

# ✅ Also provide the correct path to your test image
image_path = r"C:\Users\ayush\Downloads\Accident detection model.v2i.yolov8\test\images\test15_22_jpg.rf.5854de2847abebe0fd27cc76394f651b.jpg"

# Run inference and save the output image with bounding boxes
results = model(image_path, save=True)
# Out:
# image 1/1 C:\Users\ayush\Downloads\Accident detection model.v2i.yolov8\test\images\test15_22_jpg.rf.5854de2847abebe0fd27cc76394f651b.jpg: 640x640 1 accident, 81.8ms
# Speed: 16.3ms preprocess, 81.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict2

# %%
# ✅ Also provide the correct path to your test image
image_path = r"C:\Users\ayush\Downloads\Accident detection model.v2i.yolov8\test\images\Accidents-online-video-cutter_com-_mp4-261_jpg.rf.e10780091526483063f0c99bf6bdff56.jpg"
# Run inference and save the output image with bounding boxes
results = model(image_path, save=True)
# Out:
# image 1/1 C:\Users\ayush\Downloads\Accident detection model.v2i.yolov8\test\images\Accidents-online-video-cutter_com-_mp4-261_jpg.rf.e10780091526483063f0c99bf6bdff56.jpg: 640x640 (no detections), 114.0ms
# Speed: 3.0ms preprocess, 114.0ms inference, 12.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict2

# %%
import cv2
import matplotlib.pyplot as plt

# Read the image
img_path = r"C:\Users\ayush\Downloads\Accident detection model.v2i.yolov8\test\images\Accidents-online-video-cutter_com-_mp4-261_jpg.rf.e10780091526483063f0c99bf6bdff56.jpg"
img = cv2.imread(img_path)

# Convert BGR to RGB for displaying correctly with matplotlib
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Show the image
plt.figure(figsize=(10, 6))
plt.imshow(img_rgb)
plt.axis('off')
plt.title("Detected")
plt.show()
